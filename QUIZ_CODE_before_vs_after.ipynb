# %% [markdown]
# <a href="https://colab.research.google.com/github/maangelicatmariano/ForTheWomen/blob/master/QUIZ_CODE_before_vs_after.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **QUIZ CODE EXERCISE**

# %% [markdown]
# # BEFORE

# %%
#BEFORE

# Give the user some context.
print("\nTest how much you know about physics by trying our fun physics quiz. \n\nPlease input your personal details:")

#ask details about the quiz taker
name = input("What is your name? ")
print("\nHello, ",name+"! - , Lets begin the test!")

score = 0

#1
print("\nQuestion #1:") #prints the question
print("When light bends as it enters a different medium the process is known as what? \na. Reflection \nb. Refraction \nc. Diffraction")

answer1 = "b" #correct answer
response1 = input("Input your answer:") #asks the user to input their answer

if (response1 != answer1): # != not equal to
    score = score          # score will stay the same
else:
    score = score + 1      # else 1 point will be added to score

#2
print("\nQuestion #2:")
print("A magnifying glass is what type of lens? \na. convex \nb. concave \nc. none")

answer2 = "a"
response2 = input("Input your answer:")

if (response2 != answer2):
    score = score
else:
    score = score + 1

#3
print("\nQuestion #3:")
print("Iron is what type of magnetic material? \na. diamagnetic \nb. paramagnetic \nc. ferromagnetic")

answer3 = "c"
response3 = input("Input your answer:")

if (response3 != answer3):
    score = score
else:
    score = score + 1

#4
print("\nQuestion #4:")
print("Electric current is typically measured in what units? \na. joules \nb. amperes \nc. kilometers")

answer4 = "b"
response4 = input("Input your answer:")

if (response4 != answer4):
    score = score
else:
    score = score + 1

#5
print("\nQuestion #5:")
print("Who is the Hubble Space Telescope named after? \na. Edwin Hubble \nb. Edward Hubble \nc. Albert Einstein")

answer5 = "a"
response5 = input("Input your answer:")

if (response5 != answer5):
    score = score
else:
    score = score + 1


#6
print("\nQuestion #6:")
print("Infrared light has a wavelength that is too long or short to be visible for humans? \na. long \nb. short \nc. not sure")

answer6 = "a"
response6 = input("Input your answer:")

if (response6 != answer6):
    score = score
else:
    score = score + 1

#7
print("\nQuestion #7:")
print("What kind of eclipse do we have when the moon is between the sun and the earth? \na. Lunar eclipse \nb. solar eclipse \nc. twilight")

answer7 = "b"
response7 = input("Input your answer:")

if (response7 != answer7):
    score = score
else:
    score = score + 1

#8
print("\nQuestion #8:")
print("The most recognized model of how the universe begun is known as the? \na. Evolution \nb. Big Bang Theory \nc. theory of relativity ")

answer8 = "b"
response8 = input("Input your answer:")

if (response8 != answer8):
    score = score
else:
    score = score + 1


#9
print("\nQuestion #9:")
print("Metals expand when heated and do what when cooled? \na. expand \nb. contract \nc. stay the same")

answer9 = "b"
response9 = input("Input your answer:")

if (response9 != answer9):
    score = score
else:
    score = score + 1


#10
print("\nQuestion #10:")
print("What is the name of the famous scientist who gave us three laws of motion? \na. isaac newton \nb. albert einstein \nc. dalton newton")

answer10 = "a"
response10 = input("Input your answer:")

if (response10 != answer10):
    score = score
else:
    score = score + 1

#scoring
print("\nYour score is " + str(score) + " out of 10")
if (score >= 7):
  print( "\nYou passed! COngrats. Thank you!")
else:
  print("\nYou failed, you may try again. Thank you!")

# %% [markdown]
# # AFTER UPDATING

# %%
# Give the user some context.
print("\nTest how much you know about physics by trying our fun physics quiz. \n\nPlease input your name below-")

#ask details about the quiz taker
name = input("Name: ")
print("\nHello, ",name+"! - Lets begin the test!")

###### Functions ######
def checker(cor_ans,input_res,score):
  if cor_ans == input_res:
    score = score + 1
    return score
  else:
    return score

def pass_fail(fin_score):
  a = fin_score/len(questions)
  if a >= .7:
    print ("\nYou passed! Congrats. Thank you!")
  else:
    print("\nYou failed, you may try again. Thank you!")


###### Main ######
questions = ["\nQuestion #1:\nWhen light bends as it enters a different medium the process is known as what? \na. Reflection \nb. Refraction \nc. Diffraction",
             "\nQuestion #2:\nA magnifying glass is what type of lens? \na. convex \nb. concave \nc. meniscus",
             "\nQuestion #3:\nIron is what type of magnetic material? \na. diamagnetic \nb. paramagnetic \nc. ferromagnetic",
             "\nQuestion #4:\nElectric current is typically measured in what units? \na. joules \nb. amperes \nc. megacurie",
             "\nQuestion #5:\nWho is the Hubble Space Telescope named after? \na. Edwin Hubble \nb. Edward Hubble \nc. Galileo Galilei",
             "\nQuestion #6:\nInfrared light has a wavelength that is too long or short to be visible for humans? \na. long \nb. short \nc. 3.14mm",
             "\nQuestion #7:\nWhat kind of eclipse do we have when the moon is between the sun and the earth? \na. Lunar eclipse \nb. Solar eclipse \nc. Twilight",
             "\nQuestion #8:\nThe most recognized model of how the universe begun is known as the? \na. Evolution \nb. Big Bang Theory \nc. Theory of Relativity ",
             "\nQuestion #9:\nMetals expand when heated and do what when cooled? \na. expand \nb. contract \nc. stay the same",
             "\nQuestion #10:\nWhat is the name of the famous scientist who gave us Three Laws of Motion? \na. Isaac Newton \nb. Albert Einstein \nc. John Dalton"] 
cor_ans = ['b','a','c','b','a','a','b','b','b','a']

fin_score = 0
length = len(questions)

for i in range(length): 
  print(questions[i])
  response = input("Input your answer:")
  fin_score = checker(cor_ans[i],response,fin_score)

print("\n\nYour score is " + str(fin_score) + " out of "+ str(length))

pass_fail(fin_score)
